# %% [markdown]
# <a href="https://colab.research.google.com/github/ruupa3/sentinelsat1/blob/main/sentinelsat2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install sentinelsat
# !pip install folium
# !pip install descartes
# !pip install rasterio
# !pip install wget
# !pip install geopandas
# !pip install pandas

# %%
import folium
import numpy
import os

# %%
from sentinelsat import SentinelAPI, read_geojson, geojson_to_wkt

# %%
import geopandas
import pandas
import numpy
import rasterio
import matplotlib.pyplot as plt

# %%
from shapely.geometry import MultiPolygon, Polygon

# %%
import fiona
import wget

# %%
from sentinelsat import SentinelAPI
user = 'satarupamitra.333'
password = 'surefly@391996'
api = SentinelAPI (user, password, 'https://apihub.copernicus.eu/apihub')

# %%
# !pip install geopandas
# !pip install descartes
import geopandas as gpd
data = "/content/NDVIpractice/Nainital_footprint.shp"
shp = gpd.read_file(data)
shp.head()
# Out:
# ...
#    id                                           geometry
# 0   1  POLYGON ((78.89576 29.72363, 79.95738 29.68004...

# %%
from shapely.geometry import MultiPolygon, Polygon
footprint = None
for i in shp['geometry']:
  footprint = i

# %%
products = api.query(footprint,
    date = ('20230501', '20230510'),
    platformname = 'Sentinel-2',
    processinglevel = 'Level-2A',
    cloudcoverpercentage = (0, 10)
)

# %%
products_gdf = api.to_geodataframe(products)
products_gdf_sorted = products_gdf.sort_values(['cloudcoverpercentage'], ascending=[True])
products_gdf_sorted
# Out:
#                                                                                   title  \
# 8961dc64-7846-4292-9f19-3dade2e9bd9a  S2A_MSIL2A_20230506T051651_N0509_R062_T44RLS_2...
# 51bb17dd-f2b3-4175-9c8a-92ccde4f5fa7  S2A_MSIL2A_20230506T051651_N0509_R062_T44RMS_2...
# 4d48af8c-6f61-4fda-8a6e-cd36322a8d2e  S2A_MSIL2A_20230506T051651_N0509_R062_T44RKT_2...
# fd4101e9-394a-4f1e-a520-4f596eb056db  S2A_MSIL2A_20230506T051651_N0509_R062_T44RLT_2...
# cbe4ccd3-ab28-46a3-b8b6-349ca9a33355  S2A_MSIL2A_20230506T051651_N0509_R062_T44RKU_2...
# c6ccffbc-10e1-491f-8b88-52e49f9c940a  S2A_MSIL2A_20230506T051651_N0509_R062_T44RMT_2...
#
#                                                                                    link  \
# 8961dc64-7846-4292-9f19-3dade2e9bd9a  https://apihub.copernicus.eu/apihub/odata/v1/P...
# 51bb17dd-f2b3-4175-9c8a-92ccde4f5fa7  https://apihub.copernicus.eu/apihub/odata/v1/P...
# 4d48af8c-6f61-4fda-8a6e-cd36322a8d2e  https://apihub.copernicus.eu/apihub/odata/v1/P...
# ...

# %%
api.download_all(products)
# Out:
# ...
# LTA retrieval:   0%|          | 0/6 [00:00<?, ?product/s]
